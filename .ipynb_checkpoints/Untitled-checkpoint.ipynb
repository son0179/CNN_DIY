# %%
import random
import numpy as np
import matplotlib.pyplot as plt

from load_data import load_CIFAR10


# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cifar10_dir = 'datasets/cifar-10-batches-py'

# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# As a sanity check, we print out the size of the training and test data.
print('Training data shape: ', X_train.shape)
print(y_train)
print('Training labels shape: ', y_train.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Clear previously loaded data.
# Training data shape:  (50000, 32, 32, 3)
# [6 9 9 ... 9 1 1]
# Training labels shape:  (50000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %%
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
plt.axis('off')
samples_per_class = 10

for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y) # y_train 에서 y라벨을 갖는 원소만 가져와 새 리스트 생성
    idxs = np.random.choice(idxs, samples_per_class, replace=False) # 7개만 랜덤으로 비복원추출(중복 X)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx) # (samples_per_class) * (num_classes) 개의 그래프중 plt_idx번째 작업
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)

plt.show()

# %%
X_train = X_train.transpose(0,3,1,2)

mask = np.array(np.arange(500))

print(X_train.shape)
print(y_train.shape)

X_train = X_train[mask]#np.random.choice(X_train,500 , replace=False)   test용 데이터 개수 제한
y_train = y_train[mask] #np.random.choice(y_train,500 , replace=False)  test용 데이터 개수 제한

print(X_train.shape)
print(y_train.shape)
# Out:
# (50000, 3, 32, 32)
# (50000,)
# (500, 3, 32, 32)
# (500,)

# %%
"""
from layers import conv_forward
conv_param = { "stride":1 , "pad":1}
print(X_train.shape)
#W = np.random.randn(,)
W = np.ones((7,3,4,4))
W /= 10
print(W.shape)
conv_forward(X_train,W, 0.1 ,conv_param )
"""
# Out:
# '\nfrom layers import conv_forward\nconv_param = { "stride":1 , "pad":1}\nprint(X_train.shape)\n#W = np.random.randn(,)\nW = np.ones((7,3,4,4))\nW /= 10\nprint(W.shape)\nconv_forward(X_train,W, 0.1 ,conv_param )\n'

# %%
# 사전 준비
# 가중치 초기화 .....
from layers import *
W = np.ones((5,3,8,8))
print(X_train.shape)
conv_params = { "stride":1 , "pad":0}
print(W.shape)
#print(X_train)
firstConvlayer = ConvLayer(W.shape,conv_params,0)
out = firstConvlayer.conv_forward(X_train)
#print(out)


fisrtReLULayer = ReLULayer()
out = fisrtReLULayer.ReLU_forward( out )
#print(out)


W = np.ones((7,5,5,5))
secondConvlayer = ConvLayer(W.shape , conv_params,0.1)
out = secondConvlayer.conv_forward(out)

print(out.shape)
secondReLULayer = ReLULayer()
out = secondReLULayer.ReLU_forward( out )


Afiine = AffineLayer(out)
out = Afiine.aff_forward(out,0)
#print(out)

loss , dX = softmax(out,y_train)



print(loss)
print(dX)
print(dX.shape)
# Out:
# (500, 3, 32, 32)
# (5, 3, 8, 8)
# (500, 7, 21, 21)
# 2.207274803144226
# [[ 0.00000000e+000  4.21774484e-010  0.00000000e+000 ...  0.00000000e+000
#    0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  2.00000000e-003  0.00000000e+000 ...  0.00000000e+000
#    0.00000000e+000 -2.00000000e-003]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000 ...  0.00000000e+000
#    0.00000000e+000 -2.00000000e-003]
#  ...
#  [-2.00000000e-003  1.25964769e-196  0.00000000e+000 ...  0.00000000e+000
#    0.00000000e+000  0.00000000e+000]
#  [ 0.00000000e+000  0.00000000e+000  0.00000000e+000 ...  0.00000000e+000
#    0.00000000e+000  0.00000000e+000]
#  [ 1.83409485e-204  0.00000000e+000  0.00000000e+000 ... -2.00000000e-003
#    2.00000000e-003  0.00000000e+000]]
# (500, 10)

# %%
## 가중치 업데이트
print(dX.shape)
dX , dW , dB = Afiine.aff_backward(dX)
print("test affin back")
print(dX.shape)

dX = secondReLULayer.ReLU_backward( dX )

dX = secondConvlayer.conv_backward( dX )
print("test")
print(dX.shape)
print(dX)
# Out:
# (500, 10)
# test affin back
# (500, 7, 21, 21)
# ttt (500, 7, 21, 21) (125, 7)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-53b17add4221> in <module>
#       7 dX = secondReLULayer.ReLU_backward( dX )
#       8
# ----> 9 dX = secondConvlayer.conv_backward( dX )
#      10 print("test")
#      11 print(dX.shape)
#
# ~\Desktop\프로젝트\CNN_DIY\layers.py in conv_backward(self, dX)
#      73         """
#      74         print("ttt",dX.shape,self.col_w.shape)
# ---> 75         dcol = dX @ self.col_w.T
#      76         #dw =
#      77
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 7 is different from 21)
