# %%
import random
import numpy as np
import matplotlib.pyplot as plt

from load_data import load_CIFAR10


# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cifar10_dir = 'datasets/cifar-10-batches-py'

# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# As a sanity check, we print out the size of the training and test data.
print('Training data shape: ', X_train.shape)
print(y_train)
print('Training labels shape: ', y_train.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Clear previously loaded data.
# Training data shape:  (50000, 32, 32, 3)
# [6 9 9 ... 9 1 1]
# Training labels shape:  (50000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %%
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
plt.axis('off')
samples_per_class = 10

for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y) # y_train 에서 y라벨을 갖는 원소만 가져와 새 리스트 생성
    idxs = np.random.choice(idxs, samples_per_class, replace=False) # 7개만 랜덤으로 비복원추출(중복 X)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx) # (samples_per_class) * (num_classes) 개의 그래프중 plt_idx번째 작업
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)

plt.show()

# %%
X_train = X_train.transpose(0,3,1,2)

mask = np.array(np.arange(4000))

#print(X_train.shape)
#print(y_train.shape)

#X_train = X_train[mask]#np.random.choice(X_train,500 , replace=False)   test용 데이터 개수 제한
#y_train = y_train[mask] #np.random.choice(y_train,500 , replace=False)  test용 데이터 개수 제한

X_val = np.array(X_train[40000:,])
y_val = np.array(y_train[40000:,])
X_train = X_train[:40000,]
y_train = y_train[:40000,]
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (40000, 3, 32, 32)
# (40000,)
# (10000, 3, 32, 32)
# (10000,)
# (10000, 32, 32, 3)
# (10000,)

# %%
#
# 사전 준비
# 가중치 초기화 .....
from layers import *
W = np.ones((5,3,8,8))
print(X_train.shape)
conv_params = { "stride":1 , "pad":0}
print(W.shape)
#print(X_train)
firstConvlayer = ConvLayer(W.shape,conv_params,0)
out = firstConvlayer.conv_forward(X_train)
#print(out)


fisrtReLULayer = ReLULayer()
out = fisrtReLULayer.ReLU_forward( out )
#print(out)


W = np.ones((7,5,5,5))
secondConvlayer = ConvLayer(W.shape , conv_params,0.1)
out = secondConvlayer.conv_forward(out)

print(out.shape)
secondReLULayer = ReLULayer()
out = secondReLULayer.ReLU_forward( out )


Afiine = AffineLayer(out)
out = Afiine.aff_forward(out,0)
#print(out)

loss , dX = softmax(out,y_train)



#print(loss)
#print(dX)
#print(dX.shape)
# Out:
# (500, 3, 32, 32)
# (5, 3, 8, 8)
# (500, 7, 21, 21)

# %%
## test
## 가중치 업데이트
print(dX.shape)
dX , dW , dB = Afiine.aff_backward(dX)
print("test affin back")
print(dX.shape)

dX = secondReLULayer.ReLU_backward( dX )

dX = secondConvlayer.conv_backward( dX )

dX = fisrtReLULayer.ReLU_backward( dX )

dX = firstConvlayer.conv_backward( dX )
print("test")
#print(dX.shape)
#print(dX)
# Out:
# (500, 10)
# test affin back
# (500, 7, 21, 21)
# ttt (220500, 7) (125, 7)
# ttt (312500, 5) (192, 5)
# test
# (500, 3, 32, 32)
# [[[[-3.67735489e-06  1.54511390e-04 -3.53867873e-04 ...  2.02033150e-06
#     -2.30030389e-04 -1.58046666e-04]
#    [ 6.66590654e-05  2.08562812e-04 -2.14337332e-05 ... -2.74584113e-04
#     -2.33090827e-04 -1.85056698e-04]
#    [ 1.78341970e-04  6.83136745e-05 -1.13739667e-03 ...  1.43898744e-04
#     -2.00266431e-04 -1.76485007e-04]
#    ...
#    [-1.77574337e-04 -2.38808306e-04 -3.81353835e-04 ... -4.76630097e-05
#      3.02914208e-04  4.55884605e-05]
#    [ 9.90603012e-05 -4.55503133e-04 -9.16720235e-05 ...  2.23852969e-04
#      1.72985394e-04  8.47141932e-05]
#    ...
#    [ 6.42732784e-06  1.38865249e-04  1.70272153e-04 ...  3.53529848e-04
#     -3.79583466e-04  5.74078058e-05]
#    [ 5.74188587e-05 -4.62325261e-05  1.70551762e-04 ...  1.67089009e-04
#     -8.70544584e-05 -1.18129446e-04]
#    [-1.12244717e-04 -3.33432549e-07  3.91410829e-04 ... -2.18025001e-04
#      2.49424617e-05 -7.68888820e-05]]
#
#   [[-3.32036701e-07 -1.37369370e-04  4.63980014e-04 ...  2.37733625e-05
#     -1.32175285e-04 -2.65065267e-05]
#    [-1.54155986e-04 -1.51202744e-04  2.31777550e-04 ... -2.48120439e-04
#      1.33092691e-04 -6.73083223e-06]
#    [-2.91071161e-04 -1.10322060e-04  1.53174427e-04 ... -2.38533497e-04
#     -1.05115338e-04  9.73062261e-05]
#    ...
#    [ 1.66625077e-04 -1.26099687e-04  9.29661463e-04 ...  3.41077966e-04
#      1.96125984e-04 -1.76037229e-04]
#    [-1.27819776e-04 -1.11504701e-04 -1.09281290e-04 ... -7.64418015e-05
#      2.30529231e-04 -2.51385387e-06]
#    [ 2.08792922e-05 -1.93506123e-04  5.24982738e-05 ...  8.67098954e-05
#     -9.51310528e-05 -1.01593661e-05]]
#
#   [[ 1.06471656e-05 -3.20974592e-05  9.72798304e-06 ...  5.21371921e-06
#     -3.31330885e-05 -5.94592710e-06]
#    [-1.81294983e-05 -1.60813911e-04 -1.55056315e-04 ... -1.38611343e-04
#     -2.16748424e-04 -4.48153968e-05]
#    [-3.63283429e-05 -1.69062735e-04 -2.17416578e-04 ... -6.52645644e-06
#     -7.82533783e-06 -2.99640607e-05]
#    ...
#    [-6.33788616e-05 -5.63872211e-05  2.32075937e-04 ... -8.11437579e-05
#     -5.97647089e-05  1.16734539e-04]
#    [ 2.69996194e-04  1.04787737e-05 -2.13714848e-04 ...  8.17290809e-05
#      2.96563444e-04  1.53610103e-04]
#    [ 2.84156987e-05  1.56642778e-05  9.10513390e-05 ...  2.97068201e-04
#      1.69587513e-04  1.99067587e-04]]]]

# %%
W1 = np.ones((5,3,8,8))
W2 = np.ones((7,5,5,5))
conv_params = { "stride":1 , "pad":0}
learning_rate = 1e-7

conv1 = ConvLayer(W1.shape,conv_params,0,learing_rate)
out = firstConvlayer.conv_forward(X_train)
#print(out)+


fisrtReLULayer = ReLULayer()
out = fisrtReLULayer.ReLU_forward( out )
#print(out)


W = np.ones((7,5,5,5))
secondConvlayer = ConvLayer(W.shape , conv_params,0.1)
out = secondConvlayer.conv_forward(out)

print(out.shape)
secondReLULayer = ReLULayer()
out = secondReLULayer.ReLU_forward( out )


Afiine = AffineLayer(out)
out = Afiine.aff_forward(out,0)
#print(out)

loss , dX = softmax(out,y_train)
